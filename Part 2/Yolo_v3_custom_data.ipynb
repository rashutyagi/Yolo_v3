# %%
ls
# Out:
# drive/  sample_data/  YoloV3.rar

# %%
# !pip install pyunpack
# !pip install patool
from pyunpack import Archive
Archive("/content/YoloV3.rar").extractall("/content")

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   output	  results.txt	    train_batch0.png    weights
#  cfg		   __pycache__	  runs		    train.py
#  data		   README.md	  test_batch0.png  'ubdivisions=1'
#  detect.py	   results.json   test.py	    utils
#  models.py	   results.png	  ting		    vim.exe.stackdump

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-24 17:55:20.235892: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (480 found, 0 missing, 18 empty, 0 duplicate, for 498 images): 100% 498/498 [00:00<00:00, 10137.12it/s]
# Caching images (0.3GB): 100% 498/498 [00:01<00:00, 363.58it/s]
# Reading image shapes: 100% 498/498 [00:00<00:00, 7354.75it/s]
# ...

# %%
! python detect.py --source shinchan_video.mp4 --conf-thres 0.1 --output out_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='shinchan_video.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/1752) shinchan_video.mp4: 320x512 1 shinchans, Done. (0.017s)
# video 1/1 (2/1752) shinchan_video.mp4: 320x512 Done. (0.016s)
# video 1/1 (3/1752) shinchan_video.mp4: 320x512 1 shinchans, Done. (0.016s)
# video 1/1 (4/1752) shinchan_video.mp4: 320x512 1 shinchans, Done. (0.016s)
# video 1/1 (5/1752) shinchan_video.mp4: 320x512 Done. (0.015s)
# video 1/1 (6/1752) shinchan_video.mp4: 320x512 Done. (0.015s)
# video 1/1 (7/1752) shinchan_video.mp4: 320x512 Done. (0.015s)
# ...

# %%
! python detect.py --source shinchan_latest.mp4 --conf-thres 0.1 --output out_out
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (417/5413) shinchan_latest.mp4: 320x512 1 shinchans, Done. (0.015s)
# video 1/1 (418/5413) shinchan_latest.mp4: 320x512 1 shinchans, Done. (0.017s)
# video 1/1 (419/5413) shinchan_latest.mp4: 320x512 1 shinchans, Done. (0.015s)
# video 1/1 (420/5413) shinchan_latest.mp4: 320x512 1 shinchans, Done. (0.015s)
# video 1/1 (421/5413) shinchan_latest.mp4: 320x512 1 shinchans, Done. (0.015s)
# video 1/1 (422/5413) shinchan_latest.mp4: 320x512 1 shinchans, Done. (0.015s)
# video 1/1 (423/5413) shinchan_latest.mp4: 320x512 1 shinchans, Done. (0.015s)
# video 1/1 (424/5413) shinchan_latest.mp4: 320x512 1 shinchans, Done. (0.015s)
# video 1/1 (425/5413) shinchan_latest.mp4: 320x512 1 shinchans, Done. (0.015s)
# video 1/1 (426/5413) shinchan_latest.mp4: 320x512 1 shinchans, Done. (0.015s)
# video 1/1 (427/5413) shinchan_latest.mp4: 320x512 1 shinchans, Done. (0.015s)
# ...

# %%
! python detect.py --source Shinchan_3.mp4 --conf-thres 0.1 --output out_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='Shinchan_3.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/950) Shinchan_3.mp4: 320x512 Done. (0.017s)
# video 1/1 (2/950) Shinchan_3.mp4: 320x512 Done. (0.016s)
# video 1/1 (3/950) Shinchan_3.mp4: 320x512 Done. (0.016s)
# video 1/1 (4/950) Shinchan_3.mp4: 320x512 Done. (0.016s)
# video 1/1 (5/950) Shinchan_3.mp4: 320x512 Done. (0.016s)
# video 1/1 (6/950) Shinchan_3.mp4: 320x512 Done. (0.016s)
# video 1/1 (7/950) Shinchan_3.mp4: 320x512 Done. (0.016s)
# video 1/1 (8/950) Shinchan_3.mp4: 320x512 Done. (0.016s)
# ...
